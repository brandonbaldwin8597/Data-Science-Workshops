# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
weather = pd.read_csv('store_sharing.csv')
weather.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
weather.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
weather.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
weather.describe()
# Out:
#                 cnt            t1            t2           hum    wind_speed  \
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean    1143.101642     12.468091     11.520836     72.324954     15.913063
# std     1085.108068      5.571818      6.615145     14.313186      7.894570
# min        0.000000     -1.500000     -6.000000     20.500000      0.000000
# 25%      257.000000      8.000000      6.000000     63.000000     10.000000
# 50%      844.000000     12.500000     12.500000     74.500000     15.000000
# 75%     1671.750000     16.000000     16.000000     83.000000     20.500000
# max     7860.000000     34.000000     34.000000    100.000000     56.500000
#
#        weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000
# mean       2.722752      0.022051      0.285403      1.492075
# std        2.341163      0.146854      0.451619      1.118911
# ...

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season
sns.countplot(x='season', data=weather)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
# is_weekend
sns.countplot(x='is_weekend', data=weather)
# Out:
# <AxesSubplot:xlabel='is_weekend', ylabel='count'>

# %%
# is_holiday
sns.countplot(x='is_holiday', data=weather)
# Out:
# <AxesSubplot:xlabel='is_holiday', ylabel='count'>

# %%
# weather_code
sns.countplot(x='weather_code', data=weather)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='count'>

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
weather.timestamp.dtype
# Out:
# dtype('O')

# %%
weather.timestamp = pd.to_datetime(weather.timestamp)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
weather.set_index(weather.timestamp, inplace=True)
weather.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
weather['year_month'] = weather.index.strftime('%Y-%m')

weather['year'] = weather.index.year
weather['month'] = weather.index.month
weather['day_of_month'] = weather.index.day
weather['day_of_week'] = weather.index.dayofweek
weather['hour'] = weather.index.hour

# %%
weather.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season year_month  \
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0    2015-01
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0    2015-01
#
# ...

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize=(10, 6))
sns.heatmap(weather.corr(), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# for the target variable
new = pd.DataFrame(weather.corr().cnt)
plt.figure(figsize=(10, 6))
sns.heatmap(new, annot=True, fmt='.2f', cmap='BrBG', )

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
plt.figure(figsize=(10,6))
weather.corr()['cnt'].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x=weather.index, y='cnt', data=weather)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='cnt'>

# %%
weather[weather['cnt']>6000].sort_values('cnt', ascending=False)
# Out:
#                               timestamp   cnt    t1    t2   hum  wind_speed  \
# timestamp
# 2015-07-09 17:00:00 2015-07-09 17:00:00  7860  23.0  22.0  27.0        11.0
# 2015-07-09 08:00:00 2015-07-09 08:00:00  7531  14.5  14.5  61.0        19.0
# 2015-08-06 17:00:00 2015-08-06 17:00:00  7208  22.5  22.5  55.0        17.5
# 2015-07-09 18:00:00 2015-07-09 18:00:00  6913  22.5  21.5  29.0        13.0
# 2015-08-06 08:00:00 2015-08-06 08:00:00  6585  19.0  19.0  78.0        12.0
# 2015-08-06 18:00:00 2015-08-06 18:00:00  6394  21.5  21.5  58.5        20.0
# 2015-07-09 16:00:00 2015-07-09 16:00:00  6033  23.0  22.0  26.0        11.0
#
#                      weather_code  is_holiday  is_weekend  season year_month  \
# timestamp
# 2015-07-09 17:00:00           1.0         0.0         0.0     1.0    2015-07
# 2015-07-09 08:00:00           2.0         0.0         0.0     1.0    2015-07
# 2015-08-06 17:00:00           2.0         0.0         0.0     1.0    2015-08
# ...

# %%
fig, ax = plt.subplots()
sns.lineplot(x='t1', y='cnt', data=weather[(weather.hour==8)], hue='is_weekend')
# Out:
# <AxesSubplot:xlabel='t1', ylabel='cnt'>

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
weather_sum = pd.DataFrame(weather.groupby('year_month').cnt.sum())
weather_sum.head()
# Out:
#                cnt
# year_month
# 2015-01     546639
# 2015-02     543594
# 2015-03     695934
# 2015-04     831582
# 2015-05     895413

# %%
# with lineplot
plt.figure(figsize=(20, 5))
sns.lineplot(x='year_month', y='cnt', data=weather_sum)
plt.xticks(rotation=90);

# %%
weather.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season year_month  \
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0    2015-01
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0    2015-01
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0    2015-01
#
# ...

# %%
# with lineplot
plt.figure(figuresize=(15, 5))
sns.lineplot(x='month', y='cnt', data=weather)

# %%
# with pointplot
plt.figure(figuresize=(15, 5))
sns.pointplot(x='month', y='cnt', data=weather)

# %%
# with barplot
plt.figure(figsize=(14, 6))
sns.barplot(x='month', y='cnt', data=weather)

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='cnt', data=weather, hue='is_holiday')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
weather['is_workday'] = (weather['is_weekend'] == 1) + (weather['is_holiday'] == 1)

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='cnt', data=weather, hue='is_workday')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(15,6))
sns.lineplot(x='hour', y='cnt', data=weather, hue='season')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
# with pointplot
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(18, 15))

sns.pointplot(data=weather, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=weather, x='hour', y='cnt', hue='is_holiday')
sns.pointplot(data=weather, x='hour', y='cnt', hue='is_weekend')
sns.pointplot(data=weather, x='hour', y='cnt', hue='season')

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
plt.figure(figsize=(7, 4))
sns.barplot(x='day_of_week', y='cnt', data=weather, hue='is_weekend')
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='cnt'>

# %%
# with pointplot
plt.figure(figsize=(13,8))
plt.subplot(2, 1, 1)
sns.pointplot(x='day_of_week', y='cnt', data=weather)
plt.subplot(2, 1, 2)
sns.pointplot(x='day_of_week', y='cnt', data=weather, hue='season')
plt.tight_layout()

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
plt.figure(figsize=(15, 5))
sns.lineplot(x='day_of_month', y='cnt', data=weather)
pd.DataFrame(weather.groupby('day_of_month').cnt.mean())
# Out:
#                       cnt
# day_of_month
# 1             1077.455652
# 2             1088.117754
# 3             1127.602837
# 4             1144.492174
# 5             1140.772727
# 6             1211.227431
# 7             1194.151832
# 8             1222.696491
# 9             1261.260870
# 10            1157.453913
# 11            1203.618467
# 12            1166.952212
# 13            1139.221441
# 14            1123.670139
# 15            1175.629565
# 16            1140.871080
# 17            1182.311847
# 18            1178.552632
# 19            1153.147826
# 20            1115.667832
# 21            1125.729167
# 22            1127.717014
# 23            1173.994792
# 24            1054.147950
# 25            1190.786087
# 26            1081.516637
# 27            1130.681979
# 28            1062.750871
# 29            1079.680581
# 30            1156.406844
# 31             968.187311

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='year', y='cnt', data=weather)
# Out:
# <AxesSubplot:xlabel='year', ylabel='cnt'>

# %%
# with barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='season', y='cnt', data=weather)
# Out:
# <AxesSubplot:xlabel='season', ylabel='cnt'>

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
weather.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart
fig, ax = plt.subplots(figsize=(5,5))
ax.pie(x=weather.is_weekend.value_counts().values,
       labels=['weekday','weekend'],
       autopct='%.1f%%',
       )
plt.show()

# %%
# with countplot
fig, ax = plt.subplots(figsize=(7,5))
ax = sns.countplot(x='is_weekend',data=weather)
for bar in ax.patches:
        ax.annotate(  "%"+str(round(100*bar.get_height()/len(weather),1)) +' - '+ str(bar.get_height() ),
                    (bar.get_x()+0.2 , bar.get_height()+10) ,
                    size=12)

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
sns.countplot(x='weather_code', data=weather)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='count'>

# %%
# with catplot
g = sns.catplot(x='weather_code', col='season', data=weather, kind='count')

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
